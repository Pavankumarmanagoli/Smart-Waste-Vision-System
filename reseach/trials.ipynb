# %%
import gdown

# %%
url = "https://drive.google.com/file/d/1WzmS9RMJJyHdyrMcqdc9bsUj9XdaiV33/view?usp=sharing"

# %%
file_id = url.split("/")[-2]
file_id
# Out:
# '1WzmS9RMJJyHdyrMcqdc9bsUj9XdaiV33'

# %%
prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_id, "data/waste-detection.zip")

# %%
# %pwd
# Out:
# 'u:\\Project_Pavan\\Smart Waste Management\\reseach'
